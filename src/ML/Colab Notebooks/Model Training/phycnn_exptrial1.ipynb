# %%
# %tensorflow_version 1.x

import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
"""
@author: Ruiyang Zhang
"""

import keras
from keras.models import Sequential
from keras.layers import Dropout, Dense
from keras.optimizers import RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam, SGD
from keras.layers import Conv1D, Flatten, LSTM, Reshape, BatchNormalization, Activation, UpSampling1D, ZeroPadding1D, PReLU
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import time
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # CPU:-1; GPU0: 1; GPU1: 0;
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class DeepPhyLSTM:
    # Initialize the class
    def __init__(self, eta_tt, ag, Phi_t):

        # data
        self.eta_tt = eta_tt
        self.ag = ag
        self.Phi_t = Phi_t

        # tf placeholders and graph
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        # placeholders for data
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.eta_tt_tf = tf.placeholder(tf.float32, shape=[None, None, self.eta_tt.shape[2]])
        self.ag_tf = tf.placeholder(tf.float32, shape=[None, None, 1])

        # physics informed neural networks
        self.eta_pred, self.eta_t_pred, self.eta_tt_pred, = self.net_structure(self.ag_tf)

        # loss
        # for measurements
        self.loss = tf.reduce_mean(tf.square(self.eta_tt_tf - self.eta_tt_pred)) 

        # optimizers
        self.optimizer = tf.contrib.opt.ScipyOptimizerInterface(self.loss,
                                                                method='L-BFGS-B',
                                                                options={'maxiter': 20000,
                                                                         'maxfun': 50000,
                                                                         'maxcor': 50,
                                                                         'maxls': 50,
                                                                         'ftol': 1 * np.finfo(float).eps})

        self.optimizer_Adam = tf.train.AdamOptimizer(learning_rate = self.learning_rate)
        self.train_op = self.optimizer_Adam.minimize(self.loss)

        init = tf.global_variables_initializer()
        self.sess.run(init)

    def CNN_model(self, X):
        model = Sequential()
        model.add(Conv1D(64, 50, strides=1, padding='same', use_bias=True, input_shape=(None, 1)))
        model.add(Activation('relu'))
        model.add(Conv1D(64, 50, strides=1, padding='same', use_bias=True))
        model.add(Activation('relu'))
        model.add(Conv1D(64, 50, strides=1, padding='same', use_bias=True))
        model.add(Activation('relu'))
        model.add(Conv1D(64, 50, strides=1, padding='same', use_bias=True))
        model.add(Activation('relu'))
        model.add(Conv1D(64, 50, strides=1, padding='same', use_bias=True))
        model.add(Activation('relu'))
        model.add(Dense(50))
        model.add(Activation('relu'))
        model.add(Dense(50))
        model.add(Activation('relu'))
        model.add(Dense(self.eta_tt.shape[2]))
        y = model(X)
        return y

    def net_structure(self, ag):
        eta = self.CNN_model(ag)

        Phi_ut = np.reshape(self.Phi_t, [1, self.eta_tt.shape[1], self.eta_tt.shape[1]])
        Phi_ut = np.repeat(Phi_ut, self.eta_tt.shape[0], axis=0)
        eta_t = tf.matmul(tf.cast(Phi_ut, dtype=tf.float32), eta)
        eta_tt = tf.matmul(tf.cast(Phi_ut, dtype=tf.float32), eta_t)

        return eta, eta_t, eta_tt
    
    def train(self, num_epochs, batch_size, learning_rate, bfgs):

        Loss = []

        for epoch in range(num_epochs):
            
            N = self.eta_tt.shape[0]

            start_time = time.time()
            for it in range(0, N, batch_size):
                tf_dict = {self.eta_tt_tf: self.eta_tt, self.ag_tf: self.ag, self.learning_rate: learning_rate}
                self.sess.run(self.train_op, tf_dict)
                
                # Print
                if it % (10*batch_size) == 0:
                    elapsed = time.time() - start_time
                    loss_value, learning_rate_value = self.sess.run([self.loss, self.learning_rate], tf_dict)
                    print('Epoch: %d, It: %d, Loss: %.3e, Time: %.2f, Learning Rate: %.3e'
                          %(epoch, it/batch_size, loss_value, elapsed, learning_rate_value))
                    start_time = time.time()

            Loss.append(self.sess.run(self.loss, tf_dict))

        if bfgs == 1:
            tf_dict_all = {self.eta_tt_tf: self.eta_tt, self.ag_tf: self.ag, self.learning_rate: learning_rate}

            self.optimizer.minimize(self.sess,
                                    feed_dict=tf_dict_all,
                                    fetches=[self.loss],
                                    loss_callback=self.callback)

            Loss.append(self.sess.run(self.loss, tf_dict))

        return Loss

    def callback(self, loss):
        print('Loss:', loss)

    def predict(self, ag_star):
        
        tf_dict = {self.ag_tf: ag_star}

        eta_star = self.sess.run(self.eta_pred, tf_dict)
        eta_t_star = self.sess.run(self.eta_t_pred, tf_dict)
        eta_tt_star = self.sess.run(self.eta_tt_pred, tf_dict)

        return eta_star, eta_t_star, eta_tt_star

# %%
 if __name__ == "__main__":
   # load data
   dataDir = "/content/drive/MyDrive/Mini Project- AG2RS1-6.0/New/Data/phy/"
   mat = scipy.io.loadmat(dataDir + 'data_exp.mat')

   x_train = mat['input_tf']
   #x_train=x_train.reshape(15,3600,1)
   x_test=mat['input_pred_tf']
   #x_test=x_test.reshape(6,3600,1)
  
   y_train = mat['target_tf']
   y_train=y_train.reshape(15,1200,2)
   y_test=mat['target_pred_tf']
   y_test=y_test.reshape(6,1200,2)

   train_indices = mat['trainInd'] - 1
   test_indices = mat['valInd'] - 1
 


   dt = 0.02
     # finite difference
   n = y_train.shape[1]
   phi1 = np.concatenate([np.array([-3/ 2, 2, -1 / 2]), np.zeros([n - 3, ])])
   temp1 = np.concatenate([-1 / 2 * np.identity(n - 2), np.zeros([n - 2, 2])], axis=1)
   temp2 = np.concatenate([np.zeros([n - 2, 2]), 1 / 2 * np.identity(n - 2)], axis=1)
   phi2 = temp1 + temp2
   phi3 = np.concatenate([np.zeros([n - 3, ]), np.array([1 / 2, -2, 3 / 2])])
   Phi_t = (1 / dt) * np.concatenate(
             [np.reshape(phi1, [1, phi1.shape[0]]), phi2, np.reshape(phi3, [1, phi3.shape[0]])], axis=0)
   N_train = y_train.shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-c65988ccec90> in <module>()
#       9   #x_test=x_test.reshape(6,3600,1)
#      10
# ---> 11   y_train = mat['target_tf']
#      12   y_train=y_train.reshape(15,1200,2)
#      13   y_test=mat['target_pred_tf']
#
# KeyError: 'target_tf'

# %%
x_test.shape
# Out:
# (6, 3600)

# %%
# Training
model = DeepPhyLSTM(y_train,x_train, Phi_t)

Loss = model.train(num_epochs=12000, batch_size=N_train, learning_rate=0.01, bfgs=1)

train_loss = Loss
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
#
# Epoch: 0, It: 0, Loss: 9.497e+00, Time: 3.32, Learning Rate: 1.000e-02
# Epoch: 1, It: 0, Loss: 3.950e-01, Time: 0.07, Learning Rate: 1.000e-02
# Epoch: 2, It: 0, Loss: 1.839e-02, Time: 0.07, Learning Rate: 1.000e-02
# Epoch: 3, It: 0, Loss: 2.103e-02, Time: 0.06, Learning Rate: 1.000e-02
# Epoch: 4, It: 0, Loss: 1.971e-02, Time: 0.06, Learning Rate: 1.000e-02
# Epoch: 5, It: 0, Loss: 2.617e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 6, It: 0, Loss: 2.725e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 7, It: 0, Loss: 3.777e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 8, It: 0, Loss: 2.385e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 9, It: 0, Loss: 3.048e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 10, It: 0, Loss: 3.713e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 11, It: 0, Loss: 3.196e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 12, It: 0, Loss: 2.439e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 13, It: 0, Loss: 2.600e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 14, It: 0, Loss: 2.669e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 15, It: 0, Loss: 2.369e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 16, It: 0, Loss: 5.560e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 17, It: 0, Loss: 8.061e-02, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 18, It: 0, Loss: 1.199e-01, Time: 0.05, Learning Rate: 1.000e-02
# Epoch:
-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 112, It: 0, Loss: 2.289e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 113, It: 0, Loss: 2.289e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 114, It: 0, Loss: 2.289e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 115, It: 0, Loss: 2.289e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 116, It: 0, Loss: 2.289e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 117, It: 0, Loss: 2.289e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 118, It: 0, Loss: 2.288e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 119, It: 0, Loss: 2.288e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 120, It: 0, Loss: 2.288e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 121, It: 0, Loss: 2.288e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 122, It: 0, Loss: 2.288e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 123, It: 0, Loss: 2.287e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 124, It: 0, Loss: 2.287e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 125, It: 0, Loss: 2.287e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 126, It: 0, Loss: 2.287e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 127, It: 0, Loss: 2.287e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 128, It: 0, Loss: 2.287e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 129, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 130, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 131, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 132, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 133, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 134, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 135, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 136, It: 0, Loss: 2.286e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 137, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 138, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 139, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 140, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 141, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 142, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 143, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 144, It: 0, Loss: 2.285e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 145, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 146, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 147, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 148, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 149, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 150, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 151, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 152, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 153, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 154, It: 0, Loss: 2.284e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 155, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 156, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 157, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 158, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 159, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 160, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 161, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 162, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 163, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 164, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 165, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 166, It: 0, Loss: 2.283e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 167, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 168, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 169, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 170, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 171, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 172, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 173, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 174, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 175, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 176, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 177, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 178, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 179, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 180, It: 0, Loss: 2.282e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 181, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 182, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 183, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 184, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 185, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 186, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 187, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 188, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 189, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 190, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 191, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 192, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 193, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 194, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 195, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 196, It: 0, Loss: 2.281e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 197, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 198, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 199, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 200, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 201, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 202, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 203, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 204, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 205, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 206, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 207, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 208, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 209, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 210, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 211, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 212, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 213, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 214, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 215, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 216, It: 0, Loss: 2.280e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 217, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 218, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 219, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 220, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 221, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 222, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 223, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 224, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 225, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 226, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 227, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 228, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 229, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 230, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 231, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 232, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 233, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 234, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 235, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 236, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 237, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 238, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 239, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 240, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 241, It: 0, Loss: 2.279e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 242, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 243, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 244, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 245, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 246, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 247, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 248, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 249, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 250, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 251, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 252, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 253, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 254, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 255, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 256, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 257, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 258, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 259, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 260, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 261, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 262, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 263, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 264, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 265, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 266, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 267, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 268, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 269, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 270, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 271, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 272, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 273, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 274, It: 0, Loss: 2.278e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 275, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 276, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 277, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 278, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 279, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 280, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 281, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 282, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 283, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 284, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 285, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 286, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 287, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 288, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 289, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 290, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 291, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 292, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 293, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 294, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 295, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 296, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 297, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 298, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 299, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 300, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 301, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 302, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 303, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 304, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 305, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 306, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 307, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 308, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 309, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 310, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 311, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 312, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 313, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 314, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 315, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# Epoch: 316, It: 0, Loss: 2.277e-03, Time: 0.05, Learning Rate: 1.000e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-47dd09cef9f4> in <module>()
#       2 model = DeepPhyLSTM(y_train,x_train, Phi_t)
#       3
# ----> 4 Loss = model.train(num_epochs=12000, batch_size=N_train, learning_rate=0.01, bfgs=1)
#       5
#       6 train_loss = Loss
#
# <ipython-input-4-a035e494ec64> in train(self, num_epochs, batch_size, learning_rate, bfgs)
#      80             for it in range(0, N, batch_size):
#      81                 tf_dict = {self.eta_tt_tf: self.eta_tt, self.ag_tf: self.ag, self.learning_rate: learning_rate}
# ---> 82                 self.sess.run(self.train_op, tf_dict)
#      83
#      84                 # Print
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(np.log(train_loss), label='loss')
    # plt.plot(np.log(test_loss), label='loss_val')
plt.legend()

# %%
eta, eta_t, eta_tt = model.predict(x_train)

# %%
plt.figure()
plt.plot(y_train[5,:,0])
plt.plot(eta_tt[5,:,0])
plt.show()

# %%
y_train.shape
# Out:
# (15, 200, 2)

# %%
eta_tt.shape
# Out:
# (15, 200, 2)
